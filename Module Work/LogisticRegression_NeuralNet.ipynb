# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# Import our input dataset
diabetes_df = pd.read_csv('diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 2021-12-22 15:28:06.642041: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.7755 - accuracy: 0.4080
# Epoch 2/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.7262 - accuracy: 0.5052
# Epoch 3/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6861 - accuracy: 0.5903
# Epoch 4/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6520 - accuracy: 0.6545
# Epoch 5/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6226 - accuracy: 0.6892
# Epoch 6/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5993 - accuracy: 0.7031
# Epoch 7/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5782 - accuracy: 0.7326
# Epoch 8/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5609 - accuracy: 0.7413
# Epoch 9/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5456 - accuracy: 0.7569
# Epoch 10/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5335 - accuracy: 0.7656
# Epoch 11/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5232 - accuracy: 0.7674
# Epoch 12/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5138 - accuracy: 0.7656
# Epoch 13/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5062 - accuracy: 0.7656
# Epoch 14/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4995 - accuracy: 0.7708
# Epoch 15/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4942 - accuracy: 0.7674
# Epoch 16/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4892 - accuracy: 0.7691
# Epoch 17/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4846 - accuracy: 0.7743
# Epoch 18/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4810 - accuracy: 0.7778
# Epoch 19/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4775 - accuracy: 0.7778
# Epoch 20/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4745 - accuracy: 0.7795
# Epoch 21/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4720 - accuracy: 0.7812
# Epoch 22/50
# 18/18 [==============================] - 0s 998us/step - loss: 0.4694 - accuracy: 0.7830
# Epoch 23/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4668 - accuracy: 0.7760
# Epoch 24/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4647 - accuracy: 0.7778
# Epoch 25/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4628 - accuracy: 0.7812
# Epoch 26/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4610 - accuracy: 0.7812
# Epoch 27/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4596 - accuracy: 0.7830
# Epoch 28/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4579 - accuracy: 0.7830
# Epoch 29/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4567 - accuracy: 0.7847
# Epoch 30/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4553 - accuracy: 0.7847
# Epoch 31/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4545 - accuracy: 0.7865
# Epoch 32/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4529 - accuracy: 0.7882
# Epoch 33/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4526 - accuracy: 0.7830
# Epoch 34/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4507 - accuracy: 0.7847
# Epoch 35/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4497 - accuracy: 0.7882
# Epoch 36/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4488 - accuracy: 0.7865
# Epoch 37/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4480 - accuracy: 0.7882
# Epoch 38/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4473 - accuracy: 0.7882
# Epoch 39/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4465 - accuracy: 0.7882
# Epoch 40/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4455 - accuracy: 0.7882
# Epoch 41/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4447 - accuracy: 0.7917
# Epoch 42/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4440 - accuracy: 0.7917
# Epoch 43/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4434 - accuracy: 0.7917
# Epoch 44/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4427 - accuracy: 0.7882
# Epoch 45/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4423 - accuracy: 0.7917
# Epoch 46/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4412 - accuracy: 0.7934
# Epoch 47/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4406 - accuracy: 0.7934
# Epoch 48/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4401 - accuracy: 0.7934
# Epoch 49/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4394 - accuracy: 0.7951
# Epoch 50/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4388 - accuracy: 0.7934
# 6/6 - 0s - loss: 0.4925 - accuracy: 0.7240 - 149ms/epoch - 25ms/step
# Loss: 0.4924679100513458, Accuracy: 0.7239583134651184
